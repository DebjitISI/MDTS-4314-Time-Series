# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import acf
np.random.seed(123)
epsilon = np.random.normal(size =100004)
order =4
beta = 1/(order+1)

xt = np.empty(100000)
for i in range(4,100004):
    xt[i-4]= beta*(epsilon[i]+epsilon[i-1]+epsilon[i-2]+epsilon[i-3]+epsilon[i-4])

# %%
xt
# Out:
# array([-0.37804032,  0.1693731 , -0.51543183, ...,  0.62407193,
#         0.16785469, -0.7177595 ], shape=(100000,))

# %%
plt.plot(epsilon)

# %%
acf_values = acf(xt, nlags=50)
plt.stem(range(len(acf_values)), acf_values)
plt.title("Autocorrelation Function (ACF)")
plt.xlabel("Lag")
plt.ylabel("ACF Value")
plt.show()

# %%
acf_values = acf(epsilon, nlags=50)
plt.stem(range(len(acf_values)), acf_values)
plt.title("Autocorrelation Function (ACF)")
plt.xlabel("Lag")
plt.ylabel("ACF Value")
plt.show()
